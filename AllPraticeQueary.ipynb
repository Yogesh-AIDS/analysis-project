# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/swiggy.csv')
df
# Out:
#           ID                    Area       City                Restaurant  \
# 0        211             Koramangala  Bangalore               Tandoor Hut
# 1        221             Koramangala  Bangalore             Tunday Kababi
# 2        246               Jogupalya  Bangalore                   Kim Lee
# 3        248             Indiranagar  Bangalore         New Punjabi Hotel
# 4        249             Indiranagar  Bangalore                       Nh8
# ...      ...                     ...        ...                       ...
# 8675  464626  Panjarapole Cross Road  Ahmedabad                Malt Pizza
# 8676  465835                  Rohini      Delhi  Jay Mata Ji Home Kitchen
# 8677  465872                  Rohini      Delhi      Chinese Kitchen King
# 8678  465990                  Rohini      Delhi    Shree Ram Paratha Wala
# 8679  466488             Navrangpura  Ahmedabad              Sassy Street
#
#       Price  Avg ratings  Total ratings  \
# ...

# %%
df.head()
# Out:
#     ID         Area       City         Restaurant  Price  Avg ratings  \
# 0  211  Koramangala  Bangalore        Tandoor Hut  300.0          4.4
# 1  221  Koramangala  Bangalore      Tunday Kababi  300.0          4.1
# 2  246    Jogupalya  Bangalore            Kim Lee  650.0          4.4
# 3  248  Indiranagar  Bangalore  New Punjabi Hotel  250.0          3.9
# 4  249  Indiranagar  Bangalore                Nh8  350.0          4.0
#
#    Total ratings                                          Food type  \
# 0            100          Biryani,Chinese,North Indian,South Indian
# 1            100                                   Mughlai,Lucknowi
# 2            100                                            Chinese
# 3            500               North Indian,Punjabi,Tandoor,Chinese
# 4             50  Rajasthani,Gujarati,North Indian,Snacks,Desser...
#
#         Address  Delivery time
# 0     5Th Block             59
# 1     5Th Block             56
# 2   Double Road             50
# ...

# %%
df.tail()
# Out:
#           ID                    Area       City                Restaurant  \
# 8675  464626  Panjarapole Cross Road  Ahmedabad                Malt Pizza
# 8676  465835                  Rohini      Delhi  Jay Mata Ji Home Kitchen
# 8677  465872                  Rohini      Delhi      Chinese Kitchen King
# 8678  465990                  Rohini      Delhi    Shree Ram Paratha Wala
# 8679  466488             Navrangpura  Ahmedabad              Sassy Street
#
#       Price  Avg ratings  Total ratings                   Food type  \
# 8675  500.0          2.9             80                      Pizzas
# 8676  200.0          2.9             80                South Indian
# 8677  150.0          2.9             80      Chinese,Snacks,Tandoor
# 8678  150.0          2.9             80  North Indian,Indian,Snacks
# 8679  250.0          2.9             80        Chaat,Snacks,Chinese
#
#           Address  Delivery time
# 8675  Navrangpura             40
# 8676       Rohini             28
# ...

# %%
df.sample(5)
# Out:
#           ID              Area       City                       Restaurant  \
# 1936  153046      Himayatnagar  Hyderabad                    Huber & Holly
# 75      3369       Ashok Nagar  Bangalore                         Truffles
# 4880  402931     Shivaji Nagar       Pune  Mealful Rolls - Meals In A Roll
# 3653  343432  Sector 16 Rohini      Delhi               Chinese Veg Crunch
# 989    44261        Anna Nagar    Chennai                    Urban Spatula
#
#        Price  Avg ratings  Total ratings  \
# 1936   500.0          4.2            100
# 75     450.0          4.5           1000
# 4880   250.0          2.9             80
# 3653   300.0          4.0            100
# 989   1000.0          4.3            100
#
#                                               Food type         Address  \
# 1936  Pizzas,Beverages,Desserts,Ice Cream,Italian,Pa...  Himayath Nagar
# 75                American,Desserts,Continental,Italian  St. Marks Road
# ...

# %%
df.shape
# Out:
# (8680, 10)

# %%
df.size
# Out:
# 86800

# %%
df.columns
# Out:
# Index(['ID', 'Area', 'City', 'Restaurant', 'Price', 'Avg ratings',
#        'Total ratings', 'Food type', 'Address', 'Delivery time'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=8680, step=1)

# %%
df.dtypes
# Out:
# ID                 int64
# Area              object
# City              object
# Restaurant        object
# Price            float64
# Avg ratings      float64
# Total ratings      int64
# Food type         object
# Address           object
# Delivery time      int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8680 entries, 0 to 8679
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ID             8680 non-null   int64
#  1   Area           8680 non-null   object
#  2   City           8680 non-null   object
#  3   Restaurant     8680 non-null   object
#  4   Price          8680 non-null   float64
#  5   Avg ratings    8680 non-null   float64
#  6   Total ratings  8680 non-null   int64
#  7   Food type      8680 non-null   object
#  8   Address        8680 non-null   object
#  9   Delivery time  8680 non-null   int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 678.3+ KB

# %%
df.isnull().sum()
# Out:
# ID               0
# Area             0
# City             0
# Restaurant       0
# Price            0
# Avg ratings      0
# Total ratings    0
# Food type        0
# Address          0
# Delivery time    0
# dtype: int64

# %%
df.notnull().sum()
# Out:
# ID               8680
# Area             8680
# City             8680
# Restaurant       8680
# Price            8680
# Avg ratings      8680
# Total ratings    8680
# Food type        8680
# Address          8680
# Delivery time    8680
# dtype: int64

# %%
df.describe()
# Out:
#                   ID        Price  Avg ratings  Total ratings  Delivery time
# count    8680.000000  8680.000000  8680.000000    8680.000000    8680.000000
# mean   244812.071429   348.444470     3.655104     156.634793      53.967051
# std    158671.617188   230.940074     0.647629     391.448014      14.292335
# min       211.000000     0.000000     2.000000      20.000000      20.000000
# 25%     72664.000000   200.000000     2.900000      50.000000      44.000000
# 50%    283442.000000   300.000000     3.900000      80.000000      53.000000
# 75%    393425.250000   400.000000     4.200000     100.000000      64.000000
# max    466928.000000  2500.000000     5.000000   10000.000000     109.000000

# %%
df.sum()
# Out:
# ID                                                      2124968780
# Area             KoramangalaKoramangalaJogupalyaIndiranagarIndi...
# City             BangaloreBangaloreBangaloreBangaloreBangaloreB...
# Restaurant       Tandoor HutTunday KababiKim LeeNew Punjabi Hot...
# Price                                                    3024498.0
# Avg ratings                                                31726.3
# Total ratings                                              1359590
# Food type        Biryani,Chinese,North Indian,South IndianMughl...
# Address          5Th Block5Th BlockDouble Road80 Feet Road80 Fe...
# Delivery time                                               468434
# dtype: object

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8675    False
# 8676    False
# 8677    False
# 8678    False
# 8679    False
# Length: 8680, dtype: bool

# %%
df.drop_duplicates()
# Out:
#           ID                    Area       City                Restaurant  \
# 0        211             Koramangala  Bangalore               Tandoor Hut
# 1        221             Koramangala  Bangalore             Tunday Kababi
# 2        246               Jogupalya  Bangalore                   Kim Lee
# 3        248             Indiranagar  Bangalore         New Punjabi Hotel
# 4        249             Indiranagar  Bangalore                       Nh8
# ...      ...                     ...        ...                       ...
# 8675  464626  Panjarapole Cross Road  Ahmedabad                Malt Pizza
# 8676  465835                  Rohini      Delhi  Jay Mata Ji Home Kitchen
# 8677  465872                  Rohini      Delhi      Chinese Kitchen King
# 8678  465990                  Rohini      Delhi    Shree Ram Paratha Wala
# 8679  466488             Navrangpura  Ahmedabad              Sassy Street
#
#       Price  Avg ratings  Total ratings  \
# ...

# %%
df.unique('Area')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_2941/3374948724.py in <cell line: 0>()
# ----> 1 df.unique('Area')
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'unique'

# %%
df.nunique()
# Out:
# ID               8680
# Area              833
# City                9
# Restaurant       7865
# Price             120
# Avg ratings        30
# Total ratings       8
# Food type        3734
# Address          2339
# Delivery time      81
# dtype: int64

# %%
df.value_counts('Area')
# Out:
# Area
# Rohini                   257
# Chembur                  208
# Kothrud                  149
# Andheri East             135
# Navrangpura              132
#                         ...
# Odhav                      1
# Noble Nagar Tenament       1
# Nibm Post Office Road      1
#  Akhbar Nagar Circle       1
# Yoginagar Society          1
# Name: count, Length: 833, dtype: int64

# %%
df.sort_values('Price',ascending=False)
# Out:
#           ID               Area       City  \
# 4718  394904  Scruz Bandra East     Mumbai
# 3079  306434           Mylapore    Chennai
# 2934  294499      Vasanth Nagar  Bangalore
# 8485  439628       Brigade Road  Bangalore
# 2782  272388         Sangamvadi       Pune
# ...      ...                ...        ...
# 2830  283144              Athwa      Surat
# 6999   55710              Paldi  Ahmedabad
# 6995   55365            Isanpur  Ahmedabad
# 7218   77391           Ghodasar  Ahmedabad
# 1393   73662     Annanagar East    Chennai
#
#                                 Restaurant   Price  Avg ratings  \
# 4718  Origami Japanese & Korean Restaurant  2500.0          4.4
# 3079            Malgudi - The Savera Hotel  2500.0          4.1
# 2934           Itc Windsor - Gourmet Couch  2500.0          4.5
# 8485     Lubov Patisserie By Frozen Bottle  2000.0          2.9
# 2782                           Conrad Pune  2000.0          4.4
# ...

# %%
df.min()
# Out:
# ID                                          211
# Area                        Akhbar Nagar Circle
# City                                  Ahmedabad
# Restaurant                    Conclave At Afraa
# Price                                       0.0
# Avg ratings                                 2.0
# Total ratings                                20
# Food type        Afghani,Arabian,Indian,Tandoor
# Address                           100 Feet Road
# Delivery time                                20
# dtype: object

# %%
df['Price'].max()
# Out:
# 2500.0

# %%
df['Price'].mean()
# Out:
# np.float64(348.4444700460829)

# %%
df['Price'].median()
# Out:
# 300.0

# %%
df['Price'].mode()
# Out:
# 0    300.0
# Name: Price, dtype: float64

# %%
df.corr()['Price']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_2941/3105335750.py in <cell line: 0>()
# ----> 1 df.corr()['Price']
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   11047         cols = data.columns
#   11048         idx = cols.copy()
# > 11049         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11050
#   11051         if method == "pearson":
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1991         if dtype is not None:
#    1992             dtype = np.dtype(dtype)
# -> 1993         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994         if result.dtype is not dtype:
#    1995             result = np.asarray(result, dtype=dtype)
#
# ...

# %%
df.loc[2:10]
# Out:
#      ID         Area       City                                    Restaurant  \
# 2   246    Jogupalya  Bangalore                                       Kim Lee
# 3   248  Indiranagar  Bangalore                             New Punjabi Hotel
# 4   249  Indiranagar  Bangalore                                           Nh8
# 5   254  Indiranagar  Bangalore                                         Treat
# 6   258  Indiranagar  Bangalore                     Chinita Real Mexican Food
# 7   263  Koramangala  Bangalore  Cupcake Noggins - Cakespastries And Desserts
# 8   267       Domlur  Bangalore                                      Tea Brew
# 9   308  Koramangala  Bangalore                                    Bangaliana
# 10  435  Koramangala  Bangalore                           Bamey'S Restro Cafe
#
#      Price  Avg ratings  Total ratings  \
# 2    650.0          4.4            100
# 3    250.0          3.9            500
# 4    350.0          4.0             50
# ...

# %%
df.iloc[2:]
# Out:
#           ID                    Area       City                 Restaurant  \
# 2        246               Jogupalya  Bangalore                    Kim Lee
# 3        248             Indiranagar  Bangalore          New Punjabi Hotel
# 4        249             Indiranagar  Bangalore                        Nh8
# 5        254             Indiranagar  Bangalore                      Treat
# 6        258             Indiranagar  Bangalore  Chinita Real Mexican Food
# ...      ...                     ...        ...                        ...
# 8675  464626  Panjarapole Cross Road  Ahmedabad                 Malt Pizza
# 8676  465835                  Rohini      Delhi   Jay Mata Ji Home Kitchen
# 8677  465872                  Rohini      Delhi       Chinese Kitchen King
# 8678  465990                  Rohini      Delhi     Shree Ram Paratha Wala
# 8679  466488             Navrangpura  Ahmedabad               Sassy Street
#
#        Price  Avg ratings  Total ratings  \
# ...

# %%
df.query('Price >500')
# Out:
#           ID               Area       City                    Restaurant  \
# 2        246          Jogupalya  Bangalore                       Kim Lee
# 5        254        Indiranagar  Bangalore                         Treat
# 6        258        Indiranagar  Bangalore     Chinita Real Mexican Food
# 12       453    Pulikeshi Nagar  Bangalore                 Chichabas Taj
# 18      1050          Jayanagar  Bangalore             Nagarjuna Chimney
# ...      ...                ...        ...                           ...
# 8507  442164           Varachha      Surat  William Johns Pizza Varachha
# 8548  447543            T Nagar    Chennai                       Jalpaan
# 8573  450819              Kurla     Mumbai                   Aj'S Bistro
# 8603  452311        Navrangpura  Ahmedabad                 Devaadi Hotel
# 8662  460867  Scruz Bandra East     Mumbai              The Dessert Cake
#
#        Price  Avg ratings  Total ratings  \
# 2      650.0          4.4            100
# ...

# %%
df.rename(columns={'Price':'price'})
# Out:
#           ID                    Area       City                Restaurant  \
# 0        211             Koramangala  Bangalore               Tandoor Hut
# 1        221             Koramangala  Bangalore             Tunday Kababi
# 2        246               Jogupalya  Bangalore                   Kim Lee
# 3        248             Indiranagar  Bangalore         New Punjabi Hotel
# 4        249             Indiranagar  Bangalore                       Nh8
# ...      ...                     ...        ...                       ...
# 8675  464626  Panjarapole Cross Road  Ahmedabad                Malt Pizza
# 8676  465835                  Rohini      Delhi  Jay Mata Ji Home Kitchen
# 8677  465872                  Rohini      Delhi      Chinese Kitchen King
# 8678  465990                  Rohini      Delhi    Shree Ram Paratha Wala
# 8679  466488             Navrangpura  Ahmedabad              Sassy Street
#
#       price  Avg ratings  Total ratings  \
# ...

# %%
df['Price'].max()
# Out:
# 2500.0

# %%
df.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
sns.histplot(x='Price',data=df,y='Avg ratings')
# Out:
# <Axes: xlabel='Price', ylabel='Avg ratings'>

# %%
sns.boxplot(x='Price',data=df,y='Avg ratings')
# Out:
# <Axes: xlabel='Price', ylabel='Avg ratings'>

# %%
sns.scatterplot(x='Price',data=df,y='Avg ratings')
# Out:
# <Axes: xlabel='Price', ylabel='Avg ratings'>

# %%
sns.countplot(x='Price',data=df)
# Out:
# <Axes: xlabel='Price', ylabel='count'>

# %%
sns.pairplot(df)
plt.show()

# %%
sns.countplot(x='Price',data=df)
# Out:
# <Axes: xlabel='Price', ylabel='count'>
